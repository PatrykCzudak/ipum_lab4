# %% [markdown]
# # Data and model testing

# %%
import os

# gets rid of irritating warnings
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# ## Data preprocessing and initial quality checking
#
# We will be using [booking.com reviews dataset](https://www.kaggle.com/datasets/jiashenliu/515k-hotel-reviews-data-in-europe?resource=download), with over 500 thousand reviews of hotels. They are either positive or negative, and we will focus on review sentiment. We have [hosted it on HuggingFace](https://huggingface.co/datasets/morgul10/booking_reviews), with just the relevant columns.
#
# We will start with loading the data and initial checks - a **smoke test** of the data. Aim is to understand our dataset, and to detect obvious and serious problems. It is always a necessary process in ML.
#
# Most basic checks, which should always be performed, are:
# - data length
# - column types
# - example rows
# - exact duplicates check
# - labels distributions (for supervised problems)
# - more specific checks depending on the modality, e.g. text lengths distribution in NLP

# %%
import matplotlib.pyplot as plt
import pandas as pd

from datasets import load_dataset


df_raw = load_dataset("morgul10/booking_reviews")["train"].to_pandas()
df_neg = df_raw["Negative_Review"].str.strip()
df_pos = df_raw["Positive_Review"].str.strip()
# Out:
# Using the latest cached version of the dataset since morgul10/booking_reviews couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /var/home/student/.cache/huggingface/datasets/morgul10___booking_reviews/default/0.0.0/6e90b4b1d4a88c29de344058e9e21b5b9593665c (last modified on Sat May 24 09:34:57 2025).

# %%
print("Total data length:", len(df_raw))
print("Negative reviews:", len(df_neg))
print("Positive reviews:", len(df_pos))
# Out:
# Total data length: 515738
# Negative reviews: 515738
# Positive reviews: 515738

# %%
print("Data types:")
display(df_raw.dtypes)
# Out:
# Data types:
# Negative_Review    object
# Positive_Review    object
# dtype: object

# %%
print("First rows:")
display(df_raw.head(10))
# Out:
# First rows:
#                                      Negative_Review  \
# 0   I am so angry that i made this post available...
# 1                                        No Negative
# 2   Rooms are nice but for elderly a bit difficul...
# 3   My room was dirty and I was afraid to walk ba...
# 4   You When I booked with your company on line y...
# 5   Backyard of the hotel is total mess shouldn t...
# 6   Cleaner did not change our sheet and duvet ev...
# 7   Apart from the price for the brekfast Everyth...
# 8   Even though the pictures show very clean room...
# 9   The aircondition makes so much noise and its ...
#
#                                      Positive_Review
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
# 5   Good restaurant with modern design great chil...
# 6   The room is spacious and bright The hotel is ...
# 7   Good location Set in a lovely park friendly s...
# 8                                        No Positive
# 9   The room was big enough and the bed is good T...

# %%
print("Last rows:")
display(df_raw.tail(10))
# Out:
# Last rows:
#                                           Negative_Review  \
# 515728                                         Everything
# 515729                                        No Negative
# 515730   no free parking the room was in another build...
# 515731   No parking Public parking garage is 15 Euro p...
# 515732                                        No Negative
# 515733   no trolly or staff to help you take the lugga...
# 515734           The hotel looks like 3 but surely not 4
# 515735   The ac was useless It was a hot week in vienn...
# 515736                                        No Negative
# 515737       I was in 3rd floor It didn t work Free Wife
#
#                                           Positive_Review
# 515728                                            Nothing
# 515729   The breakfast was excelent lots of fress frui...
# 515730                                         large room
# 515731                                     Good breakfast
# 515732   helpful staff allowed me to check in early as...
# 515733                                           location
# 515734      Breakfast was ok and we got earlier check in
# 515735                                        No Positive
# 515736   The rooms are enormous and really comfortable...
# 515737                               staff was very kind

# %%
df_neg.str.len().plot.hist(title="Negative reviews lengths")
# Out:
# <Axes: title={'center': 'Negative reviews lengths'}, ylabel='Frequency'>

# %%
df_pos.str.len().plot.hist(title="Positive reviews lengths")
# Out:
# <Axes: title={'center': 'Positive reviews lengths'}, ylabel='Frequency'>

# %% [markdown]
# As you can see, the data contains quite a few "No Negatives" and "No Positive" rows. This is a widespread problem with "empty" rows, which are not really empty. They can take a form of:
# - default text, like we have here (frequent in automated forms, data from web scraping etc.)
# - empty string instead of NULL
# - deleted rows, but only marked with "deleted" column (frequent in data warehouses)
#
# Those problems can also crop up during inference (e.g., empty text), and should be handled properly.
#
# This is a particular instance of **duplicate data** problem, which is surprisingly common. Another reason may be that people writing texts don't care, e.g. input generic answers like "ok" or "everything". This biases the model, essentially putting more weights on those texts. Worse, they can have different labels, which introduces strong noise.
#
# Let's see how frequent is this problem.

# %% [markdown]
# ### Exercise 1
#
# Check the percentage of 20 most common text duplicates. This can be achieved with Pandas code conceptually similar to a combination of GROUP BY and COUNT aggregation. Check it:
# - in positive and negative subsets
# - for the whole dataset

# %%
type(df_neg)
# Out:
# pandas.core.series.Series

# %%
def top_duplicates(series: pd.Series):
    duplicates = series.value_counts().nlargest(20)
    total = len(series)
    percentage = (duplicates / total * 100).round(2)
    return pd.DataFrame({
        "text": duplicates.index,
        "count": duplicates.values,
        "percentage": percentage.values
    })

# %%
df_all = pd.concat([df_neg, df_pos]).reset_index(drop=True)

# %%
print("Top 20 duplicates in ALL reviews:")
print(top_duplicates(df_all), "\n")
# Out:
# Top 20 duplicates in ALL reviews:
#                   text   count  percentage
# 0          No Negative  127890       12.40
# 1          No Positive   35946        3.48
# 2              Nothing   19999        1.94
# 3             Location   10558        1.02
# 4           Everything    3264        0.32
# 5              nothing    2742        0.27
# 6             location    1815        0.18
# 7       Great location    1426        0.14
# 8         The location    1402        0.14
# 9        Good location    1213        0.12
# 10                None    1198        0.12
# 11           Breakfast    1113        0.11
# 12                 N A    1093        0.11
# 13                        1032        0.10
# 14               Staff     629        0.06
# 15      Friendly staff     606        0.06
# 16      Nothing really     604        0.06
# 17            All good     583        0.06
# 18  Excellent location     548        0.05
# 19                 N a     537        0.05

# %%
print("Top 20 duplicates in POSITIVE reviews:")
print(top_duplicates(df_pos))
# Out:
# Top 20 duplicates in POSITIVE reviews:
#                       text  count  percentage
# 0              No Positive  35946        6.97
# 1                 Location  10137        1.97
# 2               Everything   2897        0.56
# 3                 location   1736        0.34
# 4                  Nothing   1468        0.28
# 5           Great location   1419        0.28
# 6             The location   1341        0.26
# 7            Good location   1203        0.23
# 8                Breakfast    664        0.13
# 9           Friendly staff    603        0.12
# 10      Excellent location    547        0.11
# 11                   Staff    486        0.09
# 12      Location and staff    371        0.07
# 13              everything    371        0.07
# 14      Location was great    294        0.06
# 15       Location was good    277        0.05
# 16  Everything was perfect    276        0.05
# 17               Comfy bed    263        0.05
# 18          Good breakfast    248        0.05
# 19       Location is great    236        0.05

# %%
print("Top 20 duplicates in NEGATIVE reviews:")
print(top_duplicates(df_neg), "\n")
# Out:
# Top 20 duplicates in NEGATIVE reviews:
#                       text   count  percentage
# 0              No Negative  127890       24.80
# 1                  Nothing   18531        3.59
# 2                  nothing    2508        0.49
# 3                     None    1166        0.23
# 4                      N A    1060        0.21
# 5                              849        0.16
# 6           Nothing really     570        0.11
# 7                      N a     520        0.10
# 8                 All good     470        0.09
# 9               Small room     455        0.09
# 10           No complaints     450        0.09
# 11               Breakfast     449        0.09
# 12                Location     421        0.08
# 13          Nothing at all     415        0.08
# 14              Everything     367        0.07
# 15      Nothing to dislike     335        0.06
# 16                    none     322        0.06
# 17                   Price     301        0.06
# 18                     Nil     269        0.05
# 19  Everything was perfect     247        0.05

# %% [markdown]
# ### Manual data cleaning

# %% [markdown]
# Imagine training (and testing!) a model on data, where about 25% of negative class is duplicated, or has useless values like "none". Not a good idea, so we will remove those duplicates simply by using a case-insensitive regular expression. We will also remove words like "breakfast" or "location," which do not discriminate at all between positive and negative sentiment.

# %%
to_remove = [
    "No Negative", "No Positive", "nothing", "nothing really", "none", "n a", "na",
    "everything", "location", "the location", "breakfast", "the breakfast", "staff",
]
to_remove = [f"^{word}$" for word in to_remove]
to_remove = "|".join(to_remove)
to_remove
# Out:
# '^No Negative$|^No Positive$|^nothing$|^nothing really$|^none$|^n a$|^na$|^everything$|^location$|^the location$|^breakfast$|^the breakfast$|^staff$'

# %% [markdown]
# We will also perform two common cleaning steps: deduplication and removing empty strings. We can safely assume that people are lazy and write short, generic reviews, so there will be quite a few duplicates even after removing the most obvious cases.

# %%
df_neg_filtered = df_neg[~df_neg.str.contains(to_remove, case=False, na=True, regex=True)]
df_pos_filtered = df_pos[~df_pos.str.contains(to_remove, case=False, na=True, regex=True)]

# empty strings removal
df_neg_filtered = df_neg_filtered[df_neg_filtered.str.len() > 0]
df_pos_filtered = df_pos_filtered[df_pos_filtered.str.len() > 0]

df_neg_filtered = df_neg_filtered.reset_index(drop=True)
df_pos_filtered = df_pos_filtered.reset_index(drop=True)

df_neg_filtered = df_neg_filtered.to_frame().rename(columns={"Negative_Review": "text"})
df_pos_filtered = df_pos_filtered.to_frame().rename(columns={"Positive_Review": "text"})

df_neg_filtered["label"] = 0
df_pos_filtered["label"] = 1

print("Negative samples after filtering:", len(df_neg_filtered))
print("Positive samples after filtering:", len(df_pos_filtered))

df_all = pd.concat([df_neg_filtered, df_pos_filtered], ignore_index=True)
df_all = df_all.drop_duplicates(ignore_index=True)
# Out:
# Negative samples after filtering: 359750
# Positive samples after filtering: 459388

# %% [markdown]
# ### Sprawdzam jak to wygląda po filtrowaniu

# %%
print("Top 20 duplicates in ALL reviews:")
print(top_duplicates(df_all), "\n")
# Out:
# Top 20 duplicates in ALL reviews:
#                                                  text  count  percentage
# 0                                              (0, 0)      1         0.0
# 1   (The hotel could have informed guests prior to...      1         0.0
# 2            (The hotel could do with a make over, 0)      1         0.0
# 3   (The hotel could do with a refurbishment Rooms...      1         0.0
# 4   (The hotel could do with a restaurant room ser...      1         0.0
# 5   (The hotel could do with a revamp very old fas...      1         0.0
# 6   (The hotel could do with a small store selecti...      1         0.0
# 7   (The hotel could do with bigger signage so you...      1         0.0
# 8   (The hotel could do with brighting up as I fou...      1         0.0
# 9   (The hotel could do with investment in upgradi...      1         0.0
# 10  (The hotel could do with looking at second gla...      1         0.0
# 11  (The hotel could do with some investment great...      1         0.0
# 12  (The hotel could do with some renovations but ...      1         0.0
# 13  (The hotel could do with some updating a lick ...      1         0.0
# 14  (The hotel could give the wifi for free If you...      1         0.0
# 15  (The hotel could have a better sign at street ...      1         0.0
# 16  (The hotel could have a notice on their websit...      1         0.0
# 17                   (The hotel could have a pool, 0)      1         0.0
# 18  (The hotel could have been cleaner But was nev...      1         0.0
# 19  (The hotel could have been closer to the city ...      1         0.0

# %%
print("Top 20 duplicates in POSITIVE reviews:")
print(top_duplicates(df_pos_filtered["text"]))
# Out:
# Top 20 duplicates in POSITIVE reviews:
#                           text  count  percentage
# 0               Great location   1419        0.31
# 1                Good location   1203        0.26
# 2               Friendly staff    603        0.13
# 3           Excellent location    547        0.12
# 4           Location and staff    371        0.08
# 5           Location was great    294        0.06
# 6            Location was good    277        0.06
# 7       Everything was perfect    276        0.06
# 8                    Comfy bed    263        0.06
# 9               Good breakfast    248        0.05
# 10           Location is great    236        0.05
# 11                   The staff    234        0.05
# 12            Perfect location    227        0.05
# 13               good location    225        0.05
# 14  Location location location    218        0.05
# 15              Location staff    215        0.05
# 16            Location is good    214        0.05
# 17          Breakfast was good    198        0.04
# 18         Very friendly staff    194        0.04
# 19                       Clean    191        0.04

# %%
print("Top 20 duplicates in NEGATIVE reviews:")
print(top_duplicates(df_neg_filtered["text"]), "\n")
# Out:
# Top 20 duplicates in NEGATIVE reviews:
#                          text  count  percentage
# 0                    All good    470        0.13
# 1                  Small room    455        0.13
# 2               No complaints    450        0.13
# 3              Nothing at all    415        0.12
# 4          Nothing to dislike    335        0.09
# 5                       Price    301        0.08
# 6                         Nil    269        0.07
# 7      Everything was perfect    247        0.07
# 8                 Small rooms    245        0.07
# 9     Can t think of anything    234        0.07
# 10                    Leaving    220        0.06
# 11         Absolutely nothing    214        0.06
# 12       Everything was great    203        0.06
# 13                  Expensive    181        0.05
# 14  Nothing to complain about    178        0.05
# 15        Nothing not to like    175        0.05
# 16                  Room size    156        0.04
# 17            Having to leave    154        0.04
# 18            Very small room    153        0.04
# 19         I liked everything    145        0.04

# %% [markdown]
# Lastly, we have quite a lot of data, so we'll randomly subsample it. We will use stratification, so that the label distribution will be the same after sampling.
#
# **Modify this** depending on your hardware. Very good GPU should handle up to ~100k samples, medium-grade GPU about ~10-50k, and CPU about 5k. The more samples you process, the better the results will be.

# %%
from sklearn.utils import resample


df = resample(df_all, replace=False, n_samples=5000, random_state=0, stratify=df_all["label"])
df = df.reset_index(drop=True)
df
# Out:
#                                                    text  label
# 0     Nice staff and rooms Good breakfast choices go...      1
# 1     No heating in our room had to ask twice for he...      0
# 2                                 always clean and neat      1
# 3     Excellent friendly staff Very pleasant quiet room      1
# 4                Brilliant location for london theatres      1
# ...                                                 ...    ...
# 4995  The only complaint i have is i wished that the...      0
# 4996      Room a little dark due to external sun blinds      0
# 4997            Great staff Superb breakfast Lovely bed      1
# 4998  The beds were comfy but for what i am paying i...      0
# 4999  Great welcome at check in Very nice hotel top ...      1
#
# [5000 rows x 2 columns]

# %% [markdown]
# ## CleanLab blackbox testing
#
# [CleanLab library](https://github.com/cleanlab/cleanlab) aims to provide a blackbox, dead simple to use solution to ensure data quality. It can clean both data and labels, and works for any models. It is based on the framework of **confident learning (CL)**, originally created for detecting problems with data annotations.
#
# The main idea is as follows. A reasonably good model trained on the data should be very confident about properly annotated texts, and uncertain about ambiguous or incorrectly annotated texts. This is measured by predicted class probabilities. There are, of course, more details (e.g., class-conditioning, distinguishing model and data errors), but the general idea is really simple, and works with any data modality. It can not only detect errors, but also fix them. If another label is predicted with very high confidence, there is a high chance it's the correct one.
#
# ![flowchart.png](attachment:17e1aba2-573a-4693-a4a8-6d3f5ee8883a.png)
#
# Researchers in confidence learning, and creators of CleanLab, used this methodology in paper ["Pervasive label errors in test sets destabilize machine learning benchmarks" C.G. Northcutt et al](https://arxiv.org/abs/2103.14749). They showed that in popular text and image benchmarking datasets, up to 10% of labels are incorrect.
#
# We will take a similar approach to test our dataset. To avoid a chicken-and-egg problem (we don't have a model yet, but we need model probabilities), we need the **initial model**. A simple, yet effective approach is using a pretrained embedding model, combined with a linear classifier. This method is equivalent to freezing weights and training just the classifier head. Both embeddings and probability predictions are then used by CleanLab to detect problems.
#
# For text classification, the workflow recommended by [HuggingFace Open-Source AI Cookbook](https://huggingface.co/learn/cookbook/en/issues_in_text_dataset) is:
# 1. Compute text embeddings with a pretrained Sentence Transformer for feature extraction
# 2. Train logistic regression with cross-validation
# 3. Gather predicted probabilities (model confidence scores) for validation sets
# 4. Use CleanLab using this data
#
# Bonus: we originally detected some problems with duplicates in this dataset also by using CleanLab.

# %% [markdown]
# ### Exercise 2
#
# Implement the `get_initial_model_data()` function:
# 1. Compute text embeddings with [sentence-transformers](https://sbert.net/docs/sentence_transformer/pretrained_models.html) and `all-MiniLM-L6-v2` model.
# 2. Create `LogisticRegression` object
# 3. Train logistic regression and get probability predictions using `cross_val_predict()`. Note that it requires explicitly specifying that `predict_proba()` method should be used, in order to return probabilities, rather than 0/1 labels.

# %%
import joblib
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

def get_initial_model_data(texts: list[str], labels: np.ndarray) -> tuple[np.ndarray, np.ndarray]:

    model = SentenceTransformer("all-MiniLM-L6-v2")
    embeddings = model.encode(texts, batch_size=64, show_progress_bar=True)
    clf = make_pipeline(StandardScaler(), LogisticRegression(max_iter=1000))
    probs = cross_val_predict(clf, embeddings, labels, cv=5, method="predict_proba")
    
    return embeddings, probs

# %% [markdown]
# #### Verification

# %%
texts = df["text"].values
labels = df["label"].values

embeddings, pred_probs = get_initial_model_data(texts, labels)

assert len(embeddings) == len(pred_probs)
assert pred_probs.ndim == 2
# Out:
# Batches:   0%|          | 0/79 [00:00<?, ?it/s]

# %% [markdown]
# And now, we can use the CleanLab with the obtained embeddings and probability predictions.

# %%
from cleanlab import Datalab


data_dict = {"texts": texts, "labels": labels}
lab = Datalab(data_dict, label_name="labels", task="classification")
lab.find_issues(pred_probs=pred_probs, features=embeddings)
lab.report()
# Out:
# Finding null issues ...
# Finding label issues ...
# Finding outlier issues ...
# Finding near_duplicate issues ...
# Finding non_iid issues ...
# Finding class_imbalance issues ...
# Finding underperforming_group issues ...
#
# Audit complete. 282 issues found in the dataset.
# Dataset Information: num_examples: 5000, num_classes: 2
#
# Here is a summary of various issues found in your data:
#
#     issue_type  num_issues
#          label         244
#        outlier          27
# near_duplicate          10
#        non_iid           1
#
# Learn about each issue: https://docs.cleanlab.ai/stable/cleanlab/datalab/guide/issue_type_description.html
# See which examples in your dataset exhibit each issue via: `datalab.get_issues(<ISSUE_NAME>)`
#
# Data indices corresponding to top examples of each issue are shown below.
#
#
# ----------------------- label issues -----------------------
#
# About this issue:
# 	Examples whose given label is estimated to be potentially incorrect
#     (e.g. due to annotation error) are flagged as having label issues.
#
#
# Number of examples with this issue: 244
# Overall dataset quality in terms of this issue: 0.9584
#
# Examples representing most severe instances of this issue:
#       is_label_issue   label_score  given_label  predicted_label
# 965             True  2.637848e-07            1                0
# 3872            True  2.313031e-06            1                0
# 2085            True  4.608251e-06            1                0
# 595             True  7.040673e-06            1                0
# 1554            True  8.259995e-06            0                1
#
#
# ---------------------- outlier issues ----------------------
#
# About this issue:
# 	Examples that are very different from the rest of the dataset
#     (i.e. potentially out-of-distribution or rare/anomalous instances).
#
#
# Number of examples with this issue: 27
# Overall dataset quality in terms of this issue: 0.3808
#
# Examples representing most severe instances of this issue:
#       is_outlier_issue  outlier_score
# 1366              True       0.118210
# 4429              True       0.118283
# 2111              True       0.119122
# 2598              True       0.121236
# 3638              True       0.122115
#
#
# ------------------ near_duplicate issues -------------------
#
# About this issue:
# 	A (near) duplicate issue refers to two or more examples in
#     a dataset that are extremely similar to each other, relative
#     to the rest of the dataset.  The examples flagged with this issue
#     may be exactly duplicated, or lie atypically close together when
#     represented as vectors (i.e. feature embeddings).
#
#
# Number of examples with this issue: 10
# Overall dataset quality in terms of this issue: 0.6127
#
# Examples representing most severe instances of this issue:
#       is_near_duplicate_issue  near_duplicate_score near_duplicate_sets  distance_to_nearest_neighbor
# 3508                     True              0.082207              [4826]                      0.023592
# 4826                     True              0.082207              [3508]                      0.023592
# 3691                     True              0.089651         [4161, 336]                      0.025831
# 4161                     True              0.089651              [3691]                      0.025831
# 54                       True              0.091759              [2594]                      0.026469
#
#
# ---------------------- non_iid issues ----------------------
#
# About this issue:
# 	Whether the dataset exhibits statistically significant
#     violations of the IID assumption like:
#     changepoints or shift, drift, autocorrelation, etc.
#     The specific violation considered is whether the
#     examples are ordered such that almost adjacent examples
#     tend to have more similar feature values.
#
#
# Number of examples with this issue: 1
# Overall dataset quality in terms of this issue: 0.0000
#
# Examples representing most severe instances of this issue:
#       is_non_iid_issue  non_iid_score
# 880               True       0.661062
# 1693             False       0.671290
# 4974             False       0.684266
# 4081             False       0.701549
# 4155             False       0.717983
#
# Additional Information:
# p-value: 1.3187201717723695e-06

# %% [markdown]
# About 1.9% of duplicates, even after our cleaning, are quite expected. Many people don't really care and write short, generic reviews. Still, the data-driven approach confirms it, and we'll take a closer look at this. Additionally, about 2.2% of mislabeled data looks quite problematic.
#
# To programmatically inspect a given issue, `.get_issues()` method is used. For a given issue type (see report above for exact names), it returns a DataFrame with score for each sample. Lower score means higher risk of problems. It also returns a column with a boolean indicator whether a given sample has the problem, e.g. `is_near_duplicate_issue` or `is_label_issue`, which uses a default threshold for the score.
#
# Let's inspect the duplicate issues for now.

# %%
duplicate_issues = lab.get_issues("near_duplicate")
duplicate_issues = duplicate_issues[duplicate_issues["is_near_duplicate_issue"]]
duplicate_issues = duplicate_issues.sort_values(by="near_duplicate_score")

# %% [markdown]
# Row index indicates the row with a problem, and `near_duplicate_sets` are indices of duplicate rows. `distance_to_nearest_neighbor` measures distance between embeddings. Let's see the top 10 cases with most obvious duplicates.

# %%
for idx, row in duplicate_issues.head(10).iterrows():
    text = texts[idx]
    neighbors = texts[row["near_duplicate_sets"][:3]]
    print(f"Text: {text}")
    print(f"\tDuplicates: {neighbors}")
    print()
# Out:
# Text: Wifi slow in the room
# 	Duplicates: ['Slow wifi in our room']
#
# Text: Slow wifi in our room
# 	Duplicates: ['Wifi slow in the room']
#
# Text: very friendly staff excellent location
# 	Duplicates: ['Friendly staff excellent location' 'Staff very friendly Great location']
#
# Text: Friendly staff excellent location
# 	Duplicates: ['very friendly staff excellent location']
#
# Text: Excellent location friendly and helpful staff
# 	Duplicates: ['Good location friendly and helpful staff']
#
# Text: Good location friendly and helpful staff
# 	Duplicates: ['Excellent location friendly and helpful staff']
#
# Text: Staff very friendly Great location
# 	Duplicates: ['very friendly staff excellent location'
#  'staff are very friendly Great location']
#
# Text: Location excellent Value for money
# 	Duplicates: ['Location good value for money']
#
# Text: Location good value for money
# 	Duplicates: ['Location excellent Value for money']
#
# Text: staff are very friendly Great location
# 	Duplicates: ['Staff very friendly Great location']

# %% [markdown]
# Yeah, we forgot that `Pandas` is case-sensitive about finding duplicates. So with CleanLab, we identified a problem with our preprocessing. We will filter this in just a bit. Let's also see the last 10 duplicates.

# %%
for idx, row in duplicate_issues.tail(10).iterrows():
    text = texts[idx]
    neighbors = texts[row["near_duplicate_sets"][:3]]
    print(f"Text: {text}")
    print(f"\tDuplicates: {neighbors}")
    print()
# Out:
# Text: Wifi slow in the room
# 	Duplicates: ['Slow wifi in our room']
#
# Text: Slow wifi in our room
# 	Duplicates: ['Wifi slow in the room']
#
# Text: very friendly staff excellent location
# 	Duplicates: ['Friendly staff excellent location' 'Staff very friendly Great location']
#
# Text: Friendly staff excellent location
# 	Duplicates: ['very friendly staff excellent location']
#
# Text: Excellent location friendly and helpful staff
# 	Duplicates: ['Good location friendly and helpful staff']
#
# Text: Good location friendly and helpful staff
# 	Duplicates: ['Excellent location friendly and helpful staff']
#
# Text: Staff very friendly Great location
# 	Duplicates: ['very friendly staff excellent location'
#  'staff are very friendly Great location']
#
# Text: Location excellent Value for money
# 	Duplicates: ['Location good value for money']
#
# Text: Location good value for money
# 	Duplicates: ['Location excellent Value for money']
#
# Text: staff are very friendly Great location
# 	Duplicates: ['Staff very friendly Great location']

# %% [markdown]
# Definitely similar, but not exactly duplicates. We will remove the case-insensitive duplicates now. Note that we will keep the index to avoid recalculation for inspecting further issues.

# %%
df["text_lower"] = df["text"].str.lower()
df_deduplicated = df.drop_duplicates(subset="text_lower")
df_deduplicated = df_deduplicated.drop(columns="text_lower")
df_deduplicated = df_deduplicated.reset_index(drop=True)
df_deduplicated
# Out:
#                                                    text  label
# 0     Nice staff and rooms Good breakfast choices go...      1
# 1     No heating in our room had to ask twice for he...      0
# 2                                 always clean and neat      1
# 3     Excellent friendly staff Very pleasant quiet room      1
# 4                Brilliant location for london theatres      1
# ...                                                 ...    ...
# 4995  The only complaint i have is i wished that the...      0
# 4996      Room a little dark due to external sun blinds      0
# 4997            Great staff Superb breakfast Lovely bed      1
# 4998  The beds were comfy but for what i am paying i...      0
# 4999  Great welcome at check in Very nice hotel top ...      1
#
# [5000 rows x 2 columns]

# %% [markdown]
# Now we will inspect labels. If our model predicts the label different from the real one with very high confidence, it may be a mislabeled sample.

# %%
label_issues = lab.get_issues("label")
label_issues = label_issues[label_issues["is_label_issue"]]
label_issues = label_issues.sort_values(by="label_score")

top_label_issues_y_true = label_issues.head(10)["given_label"]
top_label_issues_y_pred = label_issues.head(10)["predicted_label"]
top_label_issues_idxs = label_issues.head(10).index
top_label_issues_texts = texts[top_label_issues_idxs]

print("Top 10 label issues")
for text, y_true, y_pred in zip(top_label_issues_texts, top_label_issues_y_true, top_label_issues_y_pred):
    print(f"y_true {y_true}, y_pred {y_pred}, text: {text}")
    print()
# Out:
# Top 10 label issues
# y_true 1, y_pred 0, text: There was a problem with the bath water not hot enough but it was solved immediately
#
# y_true 1, y_pred 0, text: Booking not carried through as the hotel decided the price was too low Lack of communication from the hotel not even an apology
#
# y_true 1, y_pred 0, text: Not all
#
# y_true 1, y_pred 0, text: Good one
#
# y_true 0, y_pred 1, text: Best the very best staff ever
#
# y_true 1, y_pred 0, text: nothing it was not worth the monies paid
#
# y_true 0, y_pred 1, text: Everything was perfect This was my favorite place to stay during my two weeks of travel
#
# y_true 0, y_pred 1, text: Excellent staff lovely
#
# y_true 0, y_pred 1, text: best location
#
# y_true 0, y_pred 1, text: Staff is very helpful

# %% [markdown]
# The reason for those is most probably that on booking.com there are separate fields for positive and negative reviews. Some people may get confused and put texts in the wrong place. So we also identified a potential UX issue, in addition to the labeling problem.
#
# We will change the labels as suggested by CleanLab.

# %%
# make sure we don't get key errors - we removed some rows earlier during deduplication
label_issues = label_issues[label_issues.index.isin(df_deduplicated.index)]

idxs = label_issues.index.tolist()
pred_labels = label_issues["predicted_label"]

df_fixed = df_deduplicated.copy()
df_fixed.loc[idxs, "label"] = pred_labels
df_fixed
# Out:
#                                                    text  label
# 0     Nice staff and rooms Good breakfast choices go...      1
# 1     No heating in our room had to ask twice for he...      0
# 2                                 always clean and neat      1
# 3     Excellent friendly staff Very pleasant quiet room      1
# 4                Brilliant location for london theatres      1
# ...                                                 ...    ...
# 4995  The only complaint i have is i wished that the...      0
# 4996      Room a little dark due to external sun blinds      0
# 4997            Great staff Superb breakfast Lovely bed      1
# 4998  The beds were comfy but for what i am paying i...      0
# 4999  Great welcome at check in Very nice hotel top ...      1
#
# [5000 rows x 2 columns]

# %% [markdown]
# ### Exercise 3
#
# 1. Print texts from the rows marked as outliers (`outlier` problem) with the strongest confidence (i.e., the lowest score).
# 2. Comment, do you think those samples really are strange? Would you remove them?

# %%
outlier_issues = lab.get_issues("outlier")
outlier_issues
# Out:
#       is_outlier_issue  outlier_score
# 0                False       0.506164
# 1                False       0.297949
# 2                False       0.307444
# 3                False       0.588618
# 4                False       0.397594
# ...                ...            ...
# 4995             False       0.314469
# 4996             False       0.289366
# 4997             False       0.474037
# 4998             False       0.466000
# 4999             False       0.458809
#
# [5000 rows x 2 columns]

# %%
outlier_issues = outlier_issues[outlier_issues["is_outlier_issue"]]
outlier_issues
# Out:
#       is_outlier_issue  outlier_score
# 18                True       0.132947
# 25                True       0.140520
# 128               True       0.134803
# 736               True       0.133282
# 986               True       0.142048
# 1024              True       0.123962
# 1284              True       0.136270
# 1366              True       0.118210
# 1378              True       0.125624
# 1392              True       0.134815
# 1440              True       0.127871
# 1791              True       0.125076
# 2111              True       0.119122
# 2321              True       0.128089
# 2340              True       0.125910
# 2351              True       0.124567
# 2598              True       0.121236
# 2897              True       0.137548
# 3465              True       0.127177
# 3596              True       0.127942
# 3638              True       0.122115
# 3812              True       0.136104
# 3892              True       0.126830
# 4429              True       0.118283
# 4469              True       0.122863
# 4725              True       0.133429
# 4902              True       0.136203

# %%
outlier_issues = outlier_issues.sort_values(by="outlier_score")
outlier_issues
# Out:
#       is_outlier_issue  outlier_score
# 1366              True       0.118210
# 4429              True       0.118283
# 2111              True       0.119122
# 2598              True       0.121236
# 3638              True       0.122115
# 4469              True       0.122863
# 1024              True       0.123962
# 2351              True       0.124567
# 1791              True       0.125076
# 1378              True       0.125624
# 2340              True       0.125910
# 3892              True       0.126830
# 3465              True       0.127177
# 1440              True       0.127871
# 3596              True       0.127942
# 2321              True       0.128089
# 18                True       0.132947
# 736               True       0.133282
# 4725              True       0.133429
# 128               True       0.134803
# 1392              True       0.134815
# 3812              True       0.136104
# 4902              True       0.136203
# 1284              True       0.136270
# 2897              True       0.137548
# 25                True       0.140520
# 986               True       0.142048

# %%
print("Top 10 najsilniejszych outlierów (najniższy outlier_score):\n")
for idx, row in outlier_issues.head(10).iterrows():
    print(f"score={row['outlier_score']:.4f}  tekst: “{texts[idx]}”\n")
# Out:
# Top 10 najsilniejszych outlierów (najniższy outlier_score):
#
# score=0.1182  tekst: “Minor isdue T V too sophistivcated”
#
# score=0.1183  tekst: “all good thanks”
#
# score=0.1191  tekst: “No have”
#
# score=0.1212  tekst: “Totul”
#
# score=0.1221  tekst: “still quite some nois”
#
# score=0.1229  tekst: “Dowdy”
#
# score=0.1240  tekst: “Nimc”
#
# score=0.1246  tekst: “M A”
#
# score=0.1251  tekst: “International connection and steam iron”
#
# score=0.1256  tekst: “Paturile suprapuse”

# %% [markdown]
# Widzimy że te z najniższym score mają literówki, obce słowa, pojdeyńcze litery. Nie da sie z tych komentarzy nic wywnioskować.

# %% [markdown]
# # Model Quality Testing
# This stage is essential for assessing the robustness, reliability, and performance of AI models developed using the curated data. Model Quality Testing enables us to verify that the model meets the intended goals and performs well across various scenarios and data subsets. This not only scrutinizes the accuracy and efficiency of models but also ensures that they are fair, accountable, and transparent in their operations.

# %% [markdown]
# ## Common metrics
#
# Now that our data is cleaned and prepared, we can train a model and proceed to test it. Firstly, we will just look at common numerical metrics, summarizing the model performance over test data. Further, we will perform **behavioral testing**, checking its stability, biases and other problems not visible when just using typical performance metrics on labels.
#
# Firstly, we will focus on just regular metrics, which use predicted probabilities and labels. Our dataset is relatively balanced, which is quite rarely the case. In any case, metrics that take label imbalance into consideration are a good choice. Well-known ones are:
# 1. Precision: if the model predicts the positive class, precision measures how sure we can be that it's really the positive class. High precision means low fraction of false positives (FP).
# 2. Recall: measures how much of the positive class the model detected. High recall means low fraction of false negatives (FN).
# 3. F1-score: a harmonic mean of precision and recall, aggregates them into one number for convenience. Harmonic mean heavily penalizes small numbers, so to get high value, both precision and recall have to be high, not just one of those.
#
# Area Under Receiver Operating Characteristic (AUROC / ROC AUC) is less frequently used in NLP, but has a few beneficial properties. It takes into consideration model probability predictions. For different thresholds (percentage above which we assume positive class) we measure the fractions of true positives and false positives, and aggregate those numbers. To achieve high AUROC, the model has to predict the right class with high probability, and avoid false positives even for low thresholds.
#
# Matthews Correlation Coefficient (MCC) can be thought of as Pearson correlation, but for binary variables. It has favorable statistical properties, and can spot model failures even when accuracy or AUROC are high. In particular, high MCC guarantees high AUROC and typically also other metrics, but not the other way around. For details, see:
# - [Wikipedia summary](https://en.wikipedia.org/wiki/Phi_coefficient#Advantages_over_accuracy_and_F1_score)
# - ["Ten quick tips for machine learning in computational biology" D. Chicco](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5721660/)
# - ["The advantages of the Matthews correlation coefficient (MCC) over F1 score and accuracy in binary classification evaluation" D. Chicco, G. Jurman](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6941312/)
# - ["The Matthews correlation coefficient (MCC) should replace the ROC AUC as the standard metric for assessing binary classification" D. Chicco, G. Jurman](https://biodatamining.biomedcentral.com/articles/10.1186/s13040-023-00322-4)
#
# Furthermore, any probabilistic metric like AUROC requires **well-calibrated** models, i.e. predicting probabilities right. Optimizing cross-entropy (log-loss) directly uses class probabilities, therefore logistic regression and neural networks typically are well-calibrated. Tree-based models, Naive Bayes or SVMs are often surprisingly bad at predicting probabilities. If a model is well-calibrated, we can trust that the probability it predicts is close to the true (typically unknown) probability.

# %% [markdown]
# ### Training a classifier
#
# We will fine-tune a simple [DistilBERT](https://huggingface.co/distilbert/distilbert-base-uncased) model (uncased variant) for binary classification. This is a typical HuggingFace code for training. We will evaluate the resulting model on many metrics, to gain more insight into its performance. During training, we will measure MCC every 1000 steps, to check how the training is progressing.

# %%
import torch
from datasets import Dataset, DatasetDict
from sklearn.model_selection import train_test_split


# 60-10-30% split
test_size = int(0.3 * len(df_fixed))
train_size = int(0.6 * len(df_fixed))

df_train, df_test = train_test_split(df_fixed, test_size=test_size, random_state=0, stratify=df_fixed["label"])
df_train, df_valid = train_test_split(df_train, train_size=train_size, random_state=0, stratify=df_train["label"])

datasets_dict = DatasetDict()
datasets_dict["train"] = Dataset.from_pandas(df_train, split="train")
datasets_dict["valid"] = Dataset.from_pandas(df_valid, split="valid")
datasets_dict["test"] = Dataset.from_pandas(df_test, split="test")

# %%
from transformers import AutoTokenizer


tokenizer = AutoTokenizer.from_pretrained("distilbert/distilbert-base-uncased")


def tokenize(examples: dict) -> dict:
    encoded_examples = tokenizer(examples["text"], padding=True, truncation=True)
    encoded_examples["label"] = torch.tensor(examples["label"])
    return encoded_examples


num_cores = joblib.cpu_count(only_physical_cores=True)
datasets_tokenized = datasets_dict.map(tokenize, batched=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %%
import os
import random

from sklearn.metrics import matthews_corrcoef
from torch.nn.functional import softmax
from transformers import AutoModelForSequenceClassification, EvalPrediction, Trainer, TrainingArguments


# set determinism settings
os.environ["PYTHONHASHSEED"] = str(0)
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed_all(0)

model = AutoModelForSequenceClassification.from_pretrained("distilbert/distilbert-base-uncased", num_labels=2)


def compute_metrics(eval_pred: EvalPrediction) -> dict:
    y_true = eval_pred.label_ids.ravel()
    logits = torch.from_numpy(eval_pred.predictions)
    y_pred_proba = softmax(logits, dim=1)[:, 1].numpy()
    y_pred = (y_pred_proba >= 0.5).astype(int)
    mcc = matthews_corrcoef(y_true, y_pred)
    return {"MCC": mcc}


training_args = TrainingArguments(
    output_dir="finetuned_model",
    learning_rate=1e-4,
    num_train_epochs=1,
    eval_strategy="steps",
    save_steps=1000,
    eval_steps=1000,
    save_total_limit=1,
    load_best_model_at_end=True,
    seed=0,
    data_seed=0,
    fp16=True,  # comment this out if you have unsupported hardware
    dataloader_num_workers=1,  # comment out if necessary
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=datasets_tokenized["train"],
    eval_dataset=datasets_tokenized["valid"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)
trainer.train()
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert/distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='375' max='375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [375/375 24:18, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=375, training_loss=0.23411503092447916, metrics={'train_runtime': 1461.9634, 'train_samples_per_second': 2.052, 'train_steps_per_second': 0.257, 'total_flos': 284705556561408.0, 'train_loss': 0.23411503092447916, 'epoch': 1.0})

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, precision_score, recall_score, roc_auc_score


pred_output = trainer.predict(datasets_tokenized["test"])
logits = torch.from_numpy(pred_output.predictions)
y_pred_proba = softmax(logits, dim=1)[:, 1].numpy()
y_pred = (y_pred_proba >= 0.5).astype(int)
y_test = datasets_tokenized["test"]["label"]

print(f"Precision: {precision_score(y_test, y_pred):.2%}")
print(f"Recall: {recall_score(y_test, y_pred):.2%}")
print(f"F1-score: {f1_score(y_test, y_pred):.2%}")
print(f"AUROC: {roc_auc_score(y_test, y_pred_proba):.2%}")
print(f"MCC: {matthews_corrcoef(y_test, y_pred):.2%}")
# Out:
# Precision: 96.31%
# Recall: 95.49%
# F1-score: 95.90%
# AUROC: 98.81%
# MCC: 91.00%

# %% [markdown]
# Generally, we seem to have a quite good classifier, but a significantly lower MCC may indicate some problems. Although, we have to remember that these are just aggregate numbers, and may lead to wrong conclusions. Let's inspect some predictions manually.
#
# The simplest way to check is to do something similar to CleanLab label check. We take the predicted probabilities and check the test instances where:
# - the model predicted the lowest probability for the positive class, or the highest probability for the negative class
# - where the model was the most uncertain, i.e., the probability was closest to 50%

# %% [markdown]
# ### Exercise 4
#
# From test data, select:
# - Ten worst false positives (with the highest predicted probability, where the true class is negative)
# - Ten worst false negatives (with the lowest predicted probability among the truly positive class)
# - Ten most uncertain predictions (with probability closest to 50%)
#
# Do you see any obvious problems here?

# %%
probs = np.array(y_pred_proba)
texts = df_test["text"].reset_index(drop=True)
true = np.array(y_test)

# %%
fp_idx = np.where(true == 0)[0]
fp_sorted = fp_idx[np.argsort(-probs[fp_idx])[:10]]

# %%
fn_idx = np.where(true == 1)[0]
fn_sorted = fn_idx[np.argsort(probs[fn_idx])[:10]]

# %%
uncertainty = np.abs(probs - 0.5)
unc_sorted = np.argsort(uncertainty)[:10]

print("=== 10 worst FALSE POSITIVES ===")
for i in fp_sorted:
    print(f"{probs[i]:.4f}\t{texts.iloc[i]}")

print("\n=== 10 worst FALSE NEGATIVES ===")
for i in fn_sorted:
    print(f"{probs[i]:.4f}\t{texts.iloc[i]}")

print("\n=== 10 MOST UNCERTAIN ===")
for i in unc_sorted:
    print(f"{probs[i]:.4f}\t{texts.iloc[i]}")
# Out:
# === 10 worst FALSE POSITIVES ===
# 0.9978	Towels linen and toiletries were of a very good quality The room was a good size
# 0.9975	The room was small but so comfortable and warm Perfect for what we wanted
# 0.9973	I booked for my son and his girlfriend and thought the deal price was excellent for the location and so did they I know they were happy with everything
# 0.9971	Location to walk around vineyard town Big bathroom even fan doesn t work though Kind staffs
# 0.9962	We were unfortunately unable to visit the restaurant during our stay however there were adequate restaurants within very easy walking distance from the hotel
# 0.9962	Yes the bed was like a cloud The personnel very friendly
# 0.9957	ROOMS ARE IN OLD STYLE AND VERY OLD FURNITURE
# 0.9943	It was good
# 0.9941	The service was excellent Nothing seemed too much trouble
# 0.9940	Free Wi fi
#
# === 10 worst FALSE NEGATIVES ===
# 0.0057	Bit noisy Soft close door mechanisms would prevent noise from slammimg doors
# 0.0060	We booked this Hotel because of the swimming pool Upon arrival we were notified that the pool was closed there was no mention of this before arrival We then tried to use the wifi in the room and were notified that there was no free wifi The staff were also pretty rude when we checking in This hotel is very overpriced for the service you receive Also do not go to the skybar it s the worst skybar I ve ever been to and extremely expensive
# 0.0064	Location tiny kitchen we didn t use but would be helpful if we stayed longer light room close to several restaurants noise level low
# 0.0070	Decorations are very Kitsch my guess is that Lewis Caroll s Alice would feel like her Wonderland here but nevertheless brand new Breakfast was ok but nothing special or very high quality Although the hotel is not central is it easy to reach it by public transportation Our option was to take the subway to Comasina and then to cross the bridge on foot and hop on bus no 41 for one stop only
# 0.0073	A little bit out from the centre so taxis to get everywhere Taxi rank outside the hotel was handy
# 0.0078	The reception staff were extremely rude insist g that they did not have a pooling under my name even asked did I ever use a different name
# 0.0092	Parking limited We were lucky to get a space
# 0.0108	The breakfast had almost too many options You could easily eat so much that lunch was not a necessity Access from two tube stations are very close As well there are a multitude of dining the in house restaurant was pretty good although a bit fancy and shopping choices that you can choose from
# 0.0114	Horrible experience
# 0.0130	had forgotten iPad charger and reception did not have one
#
# === 10 MOST UNCERTAIN ===
# 0.4985	Islington
# 0.4904	Breakfast and dinner are average
# 0.4835	Location is not close to the city but it was good to see most of Paris
# 0.4821	The location was the best for walking to all the places of interest The breakfast was rather basic for the price and I who just wanted a coffee and croissant still had to pay the full price of the buffet breakfast
# 0.5257	The difference of the interior design and the space theme
# 0.5336	I felt at home I felt special
# 0.4584	Raspberry lemonade
# 0.4472	the shower toilet in the room and the plasticness
# 0.4436	Chocolate Muffin
# 0.5599	Next to Gare De Lyon TGV

# %% [markdown]
# ## Behavioral testing with Giskard
#
# [Giskard](https://github.com/Giskard-AI/giskard) is a library for testing tabular, NLP, vision models, and LLMs. It can detect issues like over- and underconfidence, unfairness (sensitivity to gender, religion, etc.), bias towards certain words or segments, etc. There are easily usable integrations with scikit-learn, HuggingFace or LangChain.
#
# It mostly relies on **slicing** and **input perturbation** techniques. Slicing analyzes model performance in slices (segments) e.g. when specific words appear. Input perturbations (also called transformations) slightly modify the input data and compare the model behavior between original and perturbed data. These can be introducing typos, lower- or uppercase, changing gender and religion words etc.
#
# Giskard requires passing a prediction function, which takes raw test data and returns model predictions, as well as a few other configuration elements. Importantly, if we want interpretable perturbations, we need to pass raw texts as inputs, so that they can be modified. Therefore, the embedding calculation needs to be inside this prediction function. We also use the logistic classifier trained above.
#
# **Warning:** this can take a bit. If it takes too long, you can subsample the test set to make it smaller.

# %%
from giskard import Model as GiskardModel, Dataset as GiskardDataset, scan, testing
from transformers import pipeline

trained_model = trainer.model
trained_model.eval()
model_pipeline = pipeline(
    "text-classification", 
    model=trained_model, 
    tokenizer=tokenizer,
    device="cuda" if torch.cuda.is_available() else "cpu",
)


@torch.no_grad()
def prediction_function(df: pd.DataFrame) -> np.ndarray:
    pred_output = model_pipeline(df["text"].tolist())
    y_pred_proba = [pred["score"] for pred in pred_output]
    return y_pred_proba


giskard_dataset = GiskardDataset(df_test, target="label")

giskard_model = GiskardModel(
    model=prediction_function,
    model_type="classification",
    classification_labels=[0, 1],
    feature_names=["text"],
)
scan_results = scan(giskard_model, giskard_dataset, verbose=False)
display(scan_results)
# Out:
# Device set to use cpu
# 2025-05-24 14:06:38,840 pid:9948 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-05-24 14:06:38,840 pid:9948 MainThread giskard.models.automodel INFO     Your 'prediction_function' is successfully wrapped by Giskard's 'PredictionFunctionModel' wrapper class.
# 2025-05-24 14:06:38,850 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:06:39,103 pid:9948 MainThread giskard.models.base.wrapper WARNING  Please make sure that your model's output corresponds to the second label in classification_labels.
# 2025-05-24 14:06:39,105 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (10, 2) executed in 0:00:00.261142
# 2025-05-24 14:06:39,111 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:06:39,140 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.033323
# 2025-05-24 14:06:39,147 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:06:39,148 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (10, 2) executed in 0:00:00.008105
# 2025-05-24 14:06:39,161 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:08,240 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1500, 2) executed in 0:00:29.090979
# Your model is successfully validated.
# 2025-05-24 14:07:08,243 pid:9948 MainThread giskard.scanner.logger INFO     Running detectors: ['OverconfidenceDetector', 'UnderconfidenceDetector', 'SpuriousCorrelationDetector', 'DataLeakageDetector', 'PerformanceBiasDetector', 'EthicalBiasDetector', 'TextPerturbationDetector', 'NumericalPerturbationDetector', 'StochasticityDetector']
# 2025-05-24 14:07:08,243 pid:9948 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Running
# 2025-05-24 14:07:08,244 pid:9948 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Calculating loss
# 2025-05-24 14:07:08,251 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:08,254 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1500, 2) executed in 0:00:00.010168
# 2025-05-24 14:07:08,257 pid:9948 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Loss calculated (took 0:00:00.012664)
# 2025-05-24 14:07:08,258 pid:9948 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Finding data slices
# 2025-05-24 14:07:16,115 pid:9948 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: 7 slices found (took 0:00:07.856121)
# 2025-05-24 14:07:16,115 pid:9948 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Analyzing issues
# 2025-05-24 14:07:16,120 pid:9948 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-05-24 14:07:16,120 pid:9948 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Using overconfidence threshold = 0.5
# 2025-05-24 14:07:18,529 pid:9948 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: 0 issues found (took 0:00:02.413068)
# 2025-05-24 14:07:18,531 pid:9948 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Running
# 2025-05-24 14:07:18,532 pid:9948 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Calculating loss
# 2025-05-24 14:07:18,538 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:18,539 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1500, 2) executed in 0:00:00.007154
# 2025-05-24 14:07:18,540 pid:9948 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Loss calculated (took 0:00:00.008108)
# 2025-05-24 14:07:18,541 pid:9948 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Finding data slices
# 2025-05-24 14:07:32,807 pid:9948 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: 25 slices found (took 0:00:14.265955)
# 2025-05-24 14:07:32,808 pid:9948 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Analyzing issues
# 2025-05-24 14:07:32,812 pid:9948 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-05-24 14:07:35,191 pid:9948 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: 0 issues found (took 0:00:02.383435)
# 2025-05-24 14:07:35,192 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: Running
# 2025-05-24 14:07:35,198 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:35,200 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1500, 2) executed in 0:00:00.006336
# 2025-05-24 14:07:37,460 pid:9948 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-05-24 14:07:37,529 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `charset(text)` == "ascii"	Association = nan
# 2025-05-24 14:07:38,129 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "friendly"	Association = nan
# 2025-05-24 14:07:38,917 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "good"	Association = nan
# 2025-05-24 14:07:39,283 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "helpful"	Association = nan
# 2025-05-24 14:07:39,320 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "location"	Association = nan
# 2025-05-24 14:07:39,433 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "breakfast"	Association = nan
# 2025-05-24 14:07:39,821 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "staff"	Association = nan
# 2025-05-24 14:07:39,846 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "service"	Association = nan
# 2025-05-24 14:07:39,936 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "stay"	Association = nan
# 2025-05-24 14:07:40,071 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "nice"	Association = nan
# 2025-05-24 14:07:40,160 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "clean"	Association = nan
# 2025-05-24 14:07:40,433 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "small"	Association = nan
# 2025-05-24 14:07:40,578 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "rooms"	Association = nan
# 2025-05-24 14:07:41,180 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "bed"	Association = nan
# 2025-05-24 14:07:41,230 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "room"	Association = nan
# 2025-05-24 14:07:41,534 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "great"	Association = nan
# 2025-05-24 14:07:41,889 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "hotel"	Association = nan
# 2025-05-24 14:07:42,259 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "excellent"	Association = nan
# 2025-05-24 14:07:42,356 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "bathroom"	Association = nan
# 2025-05-24 14:07:42,562 pid:9948 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "comfortable"	Association = nan
# 2025-05-24 14:07:42,891 pid:9948 MainThread giskard.scanner.logger INFO     DataLeakageDetector: Running
# 2025-05-24 14:07:42,900 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:42,902 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1500, 2) executed in 0:00:00.009399
# 2025-05-24 14:07:42,906 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:42,923 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.016795
# 2025-05-24 14:07:42,925 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:42,942 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.016901
# 2025-05-24 14:07:42,944 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:42,962 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018617
# 2025-05-24 14:07:42,965 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:42,994 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.029915
# 2025-05-24 14:07:42,997 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,019 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022678
# 2025-05-24 14:07:43,023 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,042 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020104
# 2025-05-24 14:07:43,045 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,064 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020263
# 2025-05-24 14:07:43,068 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,089 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021570
# 2025-05-24 14:07:43,092 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,112 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020707
# 2025-05-24 14:07:43,115 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,133 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018955
# 2025-05-24 14:07:43,138 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,161 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022881
# 2025-05-24 14:07:43,163 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,182 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019070
# 2025-05-24 14:07:43,186 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,236 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.050925
# 2025-05-24 14:07:43,240 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,259 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019045
# 2025-05-24 14:07:43,262 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,290 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.028686
# 2025-05-24 14:07:43,294 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,312 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019397
# 2025-05-24 14:07:43,316 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,334 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019178
# 2025-05-24 14:07:43,339 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,371 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.033161
# 2025-05-24 14:07:43,374 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,392 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018572
# 2025-05-24 14:07:43,396 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,414 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019321
# 2025-05-24 14:07:43,417 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,438 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021189
# 2025-05-24 14:07:43,441 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,460 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019605
# 2025-05-24 14:07:43,463 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,484 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021438
# 2025-05-24 14:07:43,488 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,506 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019131
# 2025-05-24 14:07:43,509 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,528 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019857
# 2025-05-24 14:07:43,533 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,553 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021493
# 2025-05-24 14:07:43,557 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,576 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019533
# 2025-05-24 14:07:43,580 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,596 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.016805
# 2025-05-24 14:07:43,601 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,620 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021018
# 2025-05-24 14:07:43,624 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,644 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020490
# 2025-05-24 14:07:43,647 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,760 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.114442
# 2025-05-24 14:07:43,763 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,781 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018479
# 2025-05-24 14:07:43,784 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,804 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020838
# 2025-05-24 14:07:43,807 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,829 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022312
# 2025-05-24 14:07:43,832 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,870 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.038595
# 2025-05-24 14:07:43,874 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,891 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.017946
# 2025-05-24 14:07:43,894 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,913 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019227
# 2025-05-24 14:07:43,916 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,936 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021147
# 2025-05-24 14:07:43,939 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,958 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019841
# 2025-05-24 14:07:43,961 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:43,980 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020091
# 2025-05-24 14:07:43,984 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,006 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022977
# 2025-05-24 14:07:44,009 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,029 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020803
# 2025-05-24 14:07:44,032 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,054 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022068
# 2025-05-24 14:07:44,057 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,079 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022109
# 2025-05-24 14:07:44,082 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,123 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.041956
# 2025-05-24 14:07:44,127 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,156 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.029050
# 2025-05-24 14:07:44,160 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,182 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.023417
# 2025-05-24 14:07:44,186 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,209 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.023231
# 2025-05-24 14:07:44,213 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,234 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021208
# 2025-05-24 14:07:44,238 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,255 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.017739
# 2025-05-24 14:07:44,259 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,275 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.016361
# 2025-05-24 14:07:44,279 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,300 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021228
# 2025-05-24 14:07:44,304 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,321 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018172
# 2025-05-24 14:07:44,324 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,341 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.017626
# 2025-05-24 14:07:44,345 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,364 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019391
# 2025-05-24 14:07:44,368 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,389 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021477
# 2025-05-24 14:07:44,393 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,411 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018983
# 2025-05-24 14:07:44,416 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,434 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018766
# 2025-05-24 14:07:44,438 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,456 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018705
# 2025-05-24 14:07:44,459 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,481 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.023077
# 2025-05-24 14:07:44,484 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,505 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021674
# 2025-05-24 14:07:44,508 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,533 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.025926
# 2025-05-24 14:07:44,537 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,554 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.017944
# 2025-05-24 14:07:44,559 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,575 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.017126
# 2025-05-24 14:07:44,579 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,604 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.026200
# 2025-05-24 14:07:44,607 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,628 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021845
# 2025-05-24 14:07:44,632 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,650 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018499
# 2025-05-24 14:07:44,653 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,677 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.024873
# 2025-05-24 14:07:44,681 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,703 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022365
# 2025-05-24 14:07:44,707 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,724 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.017263
# 2025-05-24 14:07:44,728 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,748 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020890
# 2025-05-24 14:07:44,752 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,770 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018844
# 2025-05-24 14:07:44,774 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,805 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.032391
# 2025-05-24 14:07:44,810 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,828 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019220
# 2025-05-24 14:07:44,832 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,854 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022614
# 2025-05-24 14:07:44,858 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,880 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022317
# 2025-05-24 14:07:44,884 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:44,913 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.029967
# 2025-05-24 14:07:44,917 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,053 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.136490
# 2025-05-24 14:07:45,057 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,079 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.021964
# 2025-05-24 14:07:45,082 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,102 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020148
# 2025-05-24 14:07:45,106 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,124 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018993
# 2025-05-24 14:07:45,128 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,148 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020466
# 2025-05-24 14:07:45,151 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,178 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.027169
# 2025-05-24 14:07:45,182 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,200 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019309
# 2025-05-24 14:07:45,204 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,223 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020401
# 2025-05-24 14:07:45,227 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,255 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.027992
# 2025-05-24 14:07:45,258 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,278 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020230
# 2025-05-24 14:07:45,281 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,299 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018054
# 2025-05-24 14:07:45,302 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,320 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018664
# 2025-05-24 14:07:45,324 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,342 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019038
# 2025-05-24 14:07:45,346 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,366 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020772
# 2025-05-24 14:07:45,370 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,389 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019797
# 2025-05-24 14:07:45,393 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,415 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022800
# 2025-05-24 14:07:45,419 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,440 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.022034
# 2025-05-24 14:07:45,444 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,465 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020850
# 2025-05-24 14:07:45,468 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,508 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.040380
# 2025-05-24 14:07:45,512 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,531 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.019119
# 2025-05-24 14:07:45,534 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,552 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.018519
# 2025-05-24 14:07:45,556 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,573 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.017941
# 2025-05-24 14:07:45,577 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,597 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.020151
# 2025-05-24 14:07:45,600 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Running
# 2025-05-24 14:07:45,602 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Calculating loss
# 2025-05-24 14:07:45,610 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:45,612 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1500, 2) executed in 0:00:00.008666
# 2025-05-24 14:07:46,612 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Loss calculated (took 0:00:01.008616)
# 2025-05-24 14:07:46,613 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Finding data slices
# 2025-05-24 14:07:57,490 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: 19 slices found (took 0:00:10.876687)
# 2025-05-24 14:07:57,490 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Analyzing issues
# 2025-05-24 14:07:57,495 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:57,497 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1500, 2) executed in 0:00:00.006695
# 2025-05-24 14:07:57,498 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing 19 slices for performance issues.
# 2025-05-24 14:07:57,509 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "helpful"	Precision = 0.966 (global 0.547) Δm = 0.767	is_issue = False
# 2025-05-24 14:07:57,516 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "breakfast"	Precision = 0.603 (global 0.547) Δm = 0.103	is_issue = False
# 2025-05-24 14:07:57,525 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "service"	Precision = 0.556 (global 0.547) Δm = 0.016	is_issue = False
# 2025-05-24 14:07:57,534 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "stay"	Precision = 0.696 (global 0.547) Δm = 0.274	is_issue = False
# 2025-05-24 14:07:57,542 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "nice"	Precision = 0.891 (global 0.547) Δm = 0.629	is_issue = False
# 2025-05-24 14:07:57,549 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "room"	Precision = 0.506 (global 0.547) Δm = -0.074	is_issue = True
# 2025-05-24 14:07:57,566 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "hotel"	Precision = 0.675 (global 0.547) Δm = 0.235	is_issue = False
# 2025-05-24 14:07:57,574 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "good"	Precision = 0.781 (global 0.547) Δm = 0.428	is_issue = False
# 2025-05-24 14:07:57,583 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "small"	Precision = 0.226 (global 0.547) Δm = -0.586	is_issue = True
# 2025-05-24 14:07:57,598 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bathroom"	Precision = 0.417 (global 0.547) Δm = -0.238	is_issue = True
# 2025-05-24 14:07:57,615 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "friendly"	Precision = 0.944 (global 0.547) Δm = 0.727	is_issue = False
# 2025-05-24 14:07:57,623 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "location"	Precision = 0.940 (global 0.547) Δm = 0.719	is_issue = False
# 2025-05-24 14:07:57,631 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "great"	Precision = 0.903 (global 0.547) Δm = 0.653	is_issue = False
# 2025-05-24 14:07:57,639 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "excellent"	Precision = 0.954 (global 0.547) Δm = 0.745	is_issue = False
# 2025-05-24 14:07:57,647 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "comfortable"	Precision = 0.907 (global 0.547) Δm = 0.659	is_issue = False
# 2025-05-24 14:07:57,655 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "staff"	Precision = 0.833 (global 0.547) Δm = 0.524	is_issue = False
# 2025-05-24 14:07:57,663 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "clean"	Precision = 0.883 (global 0.547) Δm = 0.615	is_issue = False
# 2025-05-24 14:07:57,671 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "rooms"	Precision = 0.473 (global 0.547) Δm = -0.134	is_issue = True
# 2025-05-24 14:07:57,690 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bed"	Precision = 0.606 (global 0.547) Δm = 0.108	is_issue = False
# 2025-05-24 14:07:57,701 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "helpful"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,709 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "breakfast"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,718 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "service"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,727 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "stay"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,734 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "nice"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,742 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "room"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,750 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "hotel"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,758 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "good"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,767 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "small"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,775 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bathroom"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,783 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "friendly"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,790 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "location"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,798 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "great"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,805 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "excellent"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,813 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "comfortable"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,821 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "staff"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,829 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "clean"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,837 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "rooms"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,845 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bed"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-05-24 14:07:57,852 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "helpful"	Accuracy = 0.966 (global 0.547) Δm = 0.767	is_issue = False
# 2025-05-24 14:07:57,858 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "breakfast"	Accuracy = 0.603 (global 0.547) Δm = 0.103	is_issue = False
# 2025-05-24 14:07:57,865 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "service"	Accuracy = 0.556 (global 0.547) Δm = 0.016	is_issue = False
# 2025-05-24 14:07:57,873 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "stay"	Accuracy = 0.696 (global 0.547) Δm = 0.274	is_issue = False
# 2025-05-24 14:07:57,879 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "nice"	Accuracy = 0.891 (global 0.547) Δm = 0.629	is_issue = False
# ...
# 2025-05-24 14:07:57,970 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "comfortable"	Accuracy = 0.907 (global 0.547) Δm = 0.659	is_issue = False
# 2025-05-24 14:07:57,976 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "staff"	Accuracy = 0.833 (global 0.547) Δm = 0.524	is_issue = False
# 2025-05-24 14:07:57,984 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "clean"	Accuracy = 0.883 (global 0.547) Δm = 0.615	is_issue = False
# 2025-05-24 14:07:57,990 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "rooms"	Accuracy = 0.473 (global 0.547) Δm = -0.134	is_issue = True
# 2025-05-24 14:07:58,005 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bed"	Accuracy = 0.606 (global 0.547) Δm = 0.108	is_issue = False
# 2025-05-24 14:07:58,005 pid:9948 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: 4 issues found (took 0:00:00.514639)
# 2025-05-24 14:07:58,006 pid:9948 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Running with transformations=['Switch Gender', 'Switch Religion', 'Switch countries from high- to low-income and vice versa'] threshold=None output_sensitivity=None num_samples=None
# 2025-05-24 14:07:58,100 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:58,101 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (62, 2) executed in 0:00:00.003514
# 2025-05-24 14:07:58,104 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:59,725 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (62, 2) executed in 0:00:01.623115
# 2025-05-24 14:07:59,725 pid:9948 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Testing `text` for perturbation `Switch Gender`	Fail rate: 0.000
# 2025-05-24 14:07:59,931 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:59,932 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (2, 2) executed in 0:00:00.003677
# 2025-05-24 14:07:59,935 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:07:59,974 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (2, 2) executed in 0:00:00.041799
# 2025-05-24 14:07:59,975 pid:9948 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Testing `text` for perturbation `Switch Religion`	Fail rate: 0.000
# 2025-05-24 14:08:03,548 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:08:03,549 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (16, 2) executed in 0:00:00.003494
# 2025-05-24 14:08:03,553 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:08:04,006 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (16, 2) executed in 0:00:00.456380
# 2025-05-24 14:08:04,007 pid:9948 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Testing `text` for perturbation `Switch countries from high- to low-income and vice versa`	Fail rate: 0.000
# 2025-05-24 14:08:04,008 pid:9948 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Running with transformations=['Transform to uppercase', 'Transform to lowercase', 'Transform to title case', 'Add typos', 'Punctuation Removal', 'Transform numbers to words', 'Accent Removal'] threshold=None output_sensitivity=None num_samples=None
# 2025-05-24 14:08:04,017 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:08:04,019 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.006929
# 2025-05-24 14:08:04,026 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:08:20,737 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:16.717401
# 2025-05-24 14:08:20,738 pid:9948 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform to uppercase`	Fail rate: 0.000
# 2025-05-24 14:08:20,749 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:08:20,751 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.009395
# 2025-05-24 14:08:20,759 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:08:37,807 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:17.054077
# 2025-05-24 14:08:37,807 pid:9948 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform to lowercase`	Fail rate: 0.000
# 2025-05-24 14:08:37,819 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:08:37,821 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.007473
# 2025-05-24 14:08:37,829 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:08:55,372 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:17.550685
# 2025-05-24 14:08:55,373 pid:9948 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform to title case`	Fail rate: 0.000
# 2025-05-24 14:08:55,515 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:08:55,516 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.007231
# 2025-05-24 14:08:55,522 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:09:14,385 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:18.868525
# 2025-05-24 14:09:14,386 pid:9948 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Add typos`	Fail rate: 0.000
# 2025-05-24 14:09:14,529 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:09:14,530 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (199, 2) executed in 0:00:00.004265
# 2025-05-24 14:09:14,534 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:09:19,189 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (199, 2) executed in 0:00:04.658144
# 2025-05-24 14:09:19,190 pid:9948 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform numbers to words`	Fail rate: 0.000
# 2025-05-24 14:09:19,214 pid:9948 MainThread giskard.scanner.logger INFO     NumericalPerturbationDetector: Running with transformations=['Multiply by factor', 'Multiply by factor', 'Add Gaussian noise'] threshold=None output_sensitivity=None num_samples=None
# 2025-05-24 14:09:19,216 pid:9948 MainThread giskard.scanner.logger INFO     StochasticityDetector: Running
# 2025-05-24 14:09:19,220 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:09:20,944 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (100, 2) executed in 0:00:01.725111
# 2025-05-24 14:09:20,946 pid:9948 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-05-24 14:09:22,826 pid:9948 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (100, 2) executed in 0:00:01.880988
# <iframe id="scan-139630475163664" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#
# &lt;head&gt;
#     &lt;title&gt;Giskard Scan Results&lt;/title&gt;
#     &lt;base target=&quot;_blank&quot;&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#
# &lt;style&gt;pre code.hljs{display:block;overflow-x:auto;padding:1em}code.hljs{padding:3px 5px}
# /*!
#   Theme: GitHub Dark
#   Description: Dark theme as seen on github.com
#   Author: github.com
#   Maintainer: @Hirse
#   Updated: 2021-05-15
#
#   Outdated base version: https://github.com/primer/github-syntax-dark
#   Current colors taken from GitHub&#x27;s CSS
# */.hljs{background:#0d1117;color:#c9d1d9}.hljs-doctag,.hljs-keyword,.hljs-meta .hljs-keyword,.hljs-template-tag,.hljs-template-variable,.hljs-type,.hljs-variable.language_{color:#ff7b72}.hljs-title,.hljs-title.class_,.hljs-title.class_.inherited__,.hljs-title.function_{color:#d2a8ff}.hljs-attr,.hljs-attribute,.hljs-literal,.hljs-meta,.hljs-number,.hljs-operator,.hljs-selector-attr,.hljs-selector-class,.hljs-selector-id,.hljs-variable{color:#79c0ff}.hljs-meta .hljs-string,.hljs-regexp,.hljs-string{color:#a5d6ff}.hljs-built_in,.hljs-symbol{color:#ffa657}.hljs-code,.hljs-comment,.hljs-formula{color:#8b949e}.hljs-name,.hljs-quote,.hljs-selector-pseudo,.hljs-selector-tag{color:#7ee787}.hljs-subst{color:#c9d1d9}.hljs-section{color:#1f6feb;font-weight:700}.hljs-bullet{color:#f2cc60}.hljs-emphasis{color:#c9d1d9;font-style:italic}.hljs-strong{color:#c9d1d9;font-weight:700}.hljs-addition{background-color:#033a16;color:#aff5b4}.hljs-deletion{background-color:#67060c;color:#ffdcd7}.hljs-copy-wrapper{overflow:hidden;position:relative}.hljs-copy-button:focus,.hljs-copy-wrapper:hover .hljs-copy-button{transform:translateX(0)}.hljs-copy-button{background-color:#2d2b57;background-color:var(--hljs-theme-background);background-image:url(&#x27;data:image/svg+xml;charset=utf-8,&lt;svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;16&quot; height=&quot;16&quot; fill=&quot;none&quot; viewBox=&quot;0 0 24 24&quot;&gt;&lt;path fill=&quot;%23fff&quot; fill-rule=&quot;evenodd&quot; d=&quot;M6 5a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h12a1 1 0 0 0 1-1V6a1 1 0 0 0-1-1h-2a1 1 0 1 1 0-2h2a3 3 0 0 1 3 3v14a3 3 0 0 1-3 3H6a3 3 0 0 1-3-3V6a3 3 0 0 1 3-3h2a1 1 0 0 1 0 2H6Z&quot; clip-rule=&quot;evenodd&quot;/&gt;&lt;path fill=&quot;%23fff&quot; fill-rule=&quot;evenodd&quot; d=&quot;M7 3a2 2 0 0 1 2-2h6a2 2 0 0 1 2 2v2a2 2 0 0 1-2 2H9a2 2 0 0 1-2-2V3Zm8 0H9v2h6V3Z&quot; clip-rule=&quot;evenodd&quot;/&gt;&lt;/svg&gt;&#x27;);background-position:50%;background-repeat:no-repeat;border:1px solid #ffffff22;border-radius:.25rem;color:#fff;height:2rem;position:absolute;right:1em;text-indent:-9999px;top:1em;transition:background-color .2s ease,transform .2s ease-out;width:2rem}.hljs-copy-button:hover{border-color:#ffffff44}.hljs-copy-button:active{border-color:#ffffff66}.hljs-copy-button[data-copied=true]{background-image:none;text-indent:0;width:auto}@media (prefers-reduced-motion){.hljs-copy-button{transition:none}}.hljs-copy-alert{clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);height:1px;overflow:hidden;position:absolute;white-space:nowrap;width:1px}
# /*! tailwindcss v3.3.2 | MIT License | https://tailwindcss.com*/*,:after,:before{border:0 solid #e5e7eb;box-sizing:border-box}:after,:before{--tw-content:&quot;&quot;}html{-webkit-text-size-adjust:100%;font-feature-settings:normal;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji;font-variation-settings:normal;line-height:1.5;-moz-tab-size:4;-o-tab-size:4;tab-size:4}body{line-height:inherit;margin:0}hr{border-top-width:1px;color:inherit;height:0}abbr:where([title]){-webkit-text-decoration:underline dotted;text-decoration:underline dotted}h1,h2,h3,h4,h5,h6{font-size:inherit;font-weight:inherit}a{color:inherit;text-decoration:inherit}b,strong{font-weight:bolder}code,kbd,pre,samp{font-family:ui-monospace,SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}table{border-collapse:collapse;border-color:inherit;text-indent:0}button,input,optgroup,select,textarea{color:inherit;font-family:inherit;font-size:100%;font-weight:inherit;line-height:inherit;margin:0;padding:0}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button;background-color:transparent;background-image:none}:-moz-focusring{outline:auto}:-moz-ui-invalid{box-shadow:none}progress{vertical-align:baseline}::-webkit-inner-spin-button,::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}summary{display:list-item}blockquote,dd,dl,figure,h1,h2,h3,h4,h5,h6,hr,p,pre{margin:0}fieldset{margin:0}fieldset,legend{padding:0}menu,ol,ul{list-style:none;margin:0;padding:0}textarea{resize:vertical}input::-moz-placeholder,textarea::-moz-placeholder{color:#9ca3af;opacity:1}input::placeholder,textarea::placeholder{color:#9ca3af;opacity:1}[role=button],button{cursor:pointer}:disabled{cursor:default}audio,canvas,embed,iframe,img,object,svg,video{display:block;vertical-align:middle}img,video{height:auto;max-width:100%}[hidden]{display:none}*,:after,:before{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000;--tw-shadow-colored:0 0 #0000;--tw-blur: ;--tw-brightness: ;--tw-contrast: ;--tw-grayscale: ;--tw-hue-rotate: ;--tw-invert: ;--tw-saturate: ;--tw-sepia: ;--tw-drop-shadow: ;--tw-backdrop-blur: ;--tw-backdrop-brightness: ;--tw-backdrop-contrast: ;--tw-backdrop-grayscale: ;--tw-backdrop-hue-rotate: ;--tw-backdrop-invert: ;--tw-backdrop-opacity: ;--tw-backdrop-saturate: ;--tw-backdrop-sepia: }::backdrop{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000 ...

# %%
display(scan_results)
# Out:
# <iframe id="scan-139630475135888" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#
# &lt;head&gt;
#     &lt;title&gt;Giskard Scan Results&lt;/title&gt;
#     &lt;base target=&quot;_blank&quot;&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#
# &lt;style&gt;pre code.hljs{display:block;overflow-x:auto;padding:1em}code.hljs{padding:3px 5px}
# /*!
#   Theme: GitHub Dark
#   Description: Dark theme as seen on github.com
#   Author: github.com
#   Maintainer: @Hirse
#   Updated: 2021-05-15
#
#   Outdated base version: https://github.com/primer/github-syntax-dark
#   Current colors taken from GitHub&#x27;s CSS
# */.hljs{background:#0d1117;color:#c9d1d9}.hljs-doctag,.hljs-keyword,.hljs-meta .hljs-keyword,.hljs-template-tag,.hljs-template-variable,.hljs-type,.hljs-variable.language_{color:#ff7b72}.hljs-title,.hljs-title.class_,.hljs-title.class_.inherited__,.hljs-title.function_{color:#d2a8ff}.hljs-attr,.hljs-attribute,.hljs-literal,.hljs-meta,.hljs-number,.hljs-operator,.hljs-selector-attr,.hljs-selector-class,.hljs-selector-id,.hljs-variable{color:#79c0ff}.hljs-meta .hljs-string,.hljs-regexp,.hljs-string{color:#a5d6ff}.hljs-built_in,.hljs-symbol{color:#ffa657}.hljs-code,.hljs-comment,.hljs-formula{color:#8b949e}.hljs-name,.hljs-quote,.hljs-selector-pseudo,.hljs-selector-tag{color:#7ee787}.hljs-subst{color:#c9d1d9}.hljs-section{color:#1f6feb;font-weight:700}.hljs-bullet{color:#f2cc60}.hljs-emphasis{color:#c9d1d9;font-style:italic}.hljs-strong{color:#c9d1d9;font-weight:700}.hljs-addition{background-color:#033a16;color:#aff5b4}.hljs-deletion{background-color:#67060c;color:#ffdcd7}.hljs-copy-wrapper{overflow:hidden;position:relative}.hljs-copy-button:focus,.hljs-copy-wrapper:hover .hljs-copy-button{transform:translateX(0)}.hljs-copy-button{background-color:#2d2b57;background-color:var(--hljs-theme-background);background-image:url(&#x27;data:image/svg+xml;charset=utf-8,&lt;svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;16&quot; height=&quot;16&quot; fill=&quot;none&quot; viewBox=&quot;0 0 24 24&quot;&gt;&lt;path fill=&quot;%23fff&quot; fill-rule=&quot;evenodd&quot; d=&quot;M6 5a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h12a1 1 0 0 0 1-1V6a1 1 0 0 0-1-1h-2a1 1 0 1 1 0-2h2a3 3 0 0 1 3 3v14a3 3 0 0 1-3 3H6a3 3 0 0 1-3-3V6a3 3 0 0 1 3-3h2a1 1 0 0 1 0 2H6Z&quot; clip-rule=&quot;evenodd&quot;/&gt;&lt;path fill=&quot;%23fff&quot; fill-rule=&quot;evenodd&quot; d=&quot;M7 3a2 2 0 0 1 2-2h6a2 2 0 0 1 2 2v2a2 2 0 0 1-2 2H9a2 2 0 0 1-2-2V3Zm8 0H9v2h6V3Z&quot; clip-rule=&quot;evenodd&quot;/&gt;&lt;/svg&gt;&#x27;);background-position:50%;background-repeat:no-repeat;border:1px solid #ffffff22;border-radius:.25rem;color:#fff;height:2rem;position:absolute;right:1em;text-indent:-9999px;top:1em;transition:background-color .2s ease,transform .2s ease-out;width:2rem}.hljs-copy-button:hover{border-color:#ffffff44}.hljs-copy-button:active{border-color:#ffffff66}.hljs-copy-button[data-copied=true]{background-image:none;text-indent:0;width:auto}@media (prefers-reduced-motion){.hljs-copy-button{transition:none}}.hljs-copy-alert{clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);height:1px;overflow:hidden;position:absolute;white-space:nowrap;width:1px}
# /*! tailwindcss v3.3.2 | MIT License | https://tailwindcss.com*/*,:after,:before{border:0 solid #e5e7eb;box-sizing:border-box}:after,:before{--tw-content:&quot;&quot;}html{-webkit-text-size-adjust:100%;font-feature-settings:normal;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji;font-variation-settings:normal;line-height:1.5;-moz-tab-size:4;-o-tab-size:4;tab-size:4}body{line-height:inherit;margin:0}hr{border-top-width:1px;color:inherit;height:0}abbr:where([title]){-webkit-text-decoration:underline dotted;text-decoration:underline dotted}h1,h2,h3,h4,h5,h6{font-size:inherit;font-weight:inherit}a{color:inherit;text-decoration:inherit}b,strong{font-weight:bolder}code,kbd,pre,samp{font-family:ui-monospace,SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}table{border-collapse:collapse;border-color:inherit;text-indent:0}button,input,optgroup,select,textarea{color:inherit;font-family:inherit;font-size:100%;font-weight:inherit;line-height:inherit;margin:0;padding:0}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button;background-color:transparent;background-image:none}:-moz-focusring{outline:auto}:-moz-ui-invalid{box-shadow:none}progress{vertical-align:baseline}::-webkit-inner-spin-button,::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}summary{display:list-item}blockquote,dd,dl,figure,h1,h2,h3,h4,h5,h6,hr,p,pre{margin:0}fieldset{margin:0}fieldset,legend{padding:0}menu,ol,ul{list-style:none;margin:0;padding:0}textarea{resize:vertical}input::-moz-placeholder,textarea::-moz-placeholder{color:#9ca3af;opacity:1}input::placeholder,textarea::placeholder{color:#9ca3af;opacity:1}[role=button],button{cursor:pointer}:disabled{cursor:default}audio,canvas,embed,iframe,img,object,svg,video{display:block;vertical-align:middle}img,video{height:auto;max-width:100%}[hidden]{display:none}*,:after,:before{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000;--tw-shadow-colored:0 0 #0000;--tw-blur: ;--tw-brightness: ;--tw-contrast: ;--tw-grayscale: ;--tw-hue-rotate: ;--tw-invert: ;--tw-saturate: ;--tw-sepia: ;--tw-drop-shadow: ;--tw-backdrop-blur: ;--tw-backdrop-brightness: ;--tw-backdrop-contrast: ;--tw-backdrop-grayscale: ;--tw-backdrop-hue-rotate: ;--tw-backdrop-invert: ;--tw-backdrop-opacity: ;--tw-backdrop-saturate: ;--tw-backdrop-sepia: }::backdrop{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000 ...

# %% [markdown]
# We have only a few issues. Perfect. We have performance problems in some segments, containing words like "small" or "bathroom". Fixing such issues is often not straightforward, however, and generally requires more data, or data augmentation with e.g. [nlpaug](https://github.com/makcedward/nlpaug) library. Typically, fixing many of these issues is quite hard, but just being aware of them can be useful.

# %% [markdown]
# # Interpretability
# Interpretability is a fundamental aspect of developing trustworthy and effective AI systems, particularly when decisions made by these systems have significant implications. It involves understanding and explaining how AI models make their decisions, which is crucial for gaining user trust, fulfilling regulatory requirements, and facilitating model debugging and improvement. It bridges the gap between advanced computational models and human understanding, ensuring that AI systems are not only powerful and efficient but also aligned with ethical standards and user expectations.

# %% [markdown]
# ## Global vs local explainability
#
# Understanding the overall behavior of the model is known as **global explainability**, and is generally tough. Modern NLP models are incredibly complex and basically impossible to summarize like "if description mentions small room, then predict negative sentiment". This is also less interesting to end users, who are often interested in understanding prediction for a single given text, known as **local interpretability**.
#
# There are a lot of techniques for this, benchmarked in papers:
# - ["A Diagnostic Study of Explainability Techniques for Text Classification" P. Atanasova et al.](https://aclanthology.org/2020.emnlp-main.263/)
# - ["A Multilingual Perspective Towards the Evaluation of Attribution Methods in Natural Language Inference" K. Zaman, Y. Belinkov](https://aclanthology.org/2022.emnlp-main.101/)
#
# Interestingly, both papers and our practical experience show that the simplest **gradient attribution** methods perform the best. They are fast, faithful to the inner workings of the model, and make sense for human evaluators. Concretely, InputXGradient method with either mean or L2 normalization per word gives the best results. In short, it works as follows:
# 1. Compute model prediction with gradients, just like during training, but without updating model weights.
# 2. With backpropagation, compute gradient for each input token, also known as saliency or **attribution**.
# 3. Multiply tokens by their gradient (hence the name), getting token attribution vector.
# 4. Normalize attribution, i.e., calculate either average or L2-normalized score for each word.
#
# This way, we get a single number per token. Gradients are computed for a given class. For binary classification, we predict the probability of positive class. Therefore, higher scores indicate that tokens increase the probability, and negative scores mean that they decrease probability.
#
# Why does this simple method work very well? We don't really know. There are some hypotheses, but they are of high mathematical complexity. If you're interested, see e.g. ["The Manifold Hypothesis for Gradient-Based Explanations" S. Bordt et al](https://openaccess.thecvf.com/content/CVPR2023W/XAI4CV/papers/Bordt_The_Manifold_Hypothesis_for_Gradient-Based_Explanations_CVPRW_2023_paper.pdf). A major advantage is also speed. This requires computing gradients, but it's still just one forward and backward pass through the model. Other methods are much more complex, like SHAP for text, which has almost exponential complexity.

# %% [markdown]
# ## Local explainability with Captum
#
# [Captum](https://captum.ai/) is the most popular model interpretability library for PyTorch. It works for computer vision, NLP, [LLMs](https://captum.ai/tutorials/Llama2_LLM_Attribution) and other models. While the most important part are model attributions, which we will use to understand inputs, Captum also supports adversarial attacks, neuron and layer explanations, and identifying influential examples.
#
# The code below is modified from [Captum question answering tutorial](https://captum.ai/tutorials/Bert_SQUAD_Interpret). Firstly, we tokenize texts. The essential part is calling the `configure_interpretable_embedding_layer()` function - this special embedding layer replaces the existing transformer embedding layer with Captum one, which tracks gradients and combines explanations with original tokens. Furthermore, since Captum requires gradients, we need to make a small wrapper to pass `attention_mask` to our transformer. Lastly, we make the overall model prediction and use built-in visualization methods to plot the results.

# %%
from copy import deepcopy

from captum.attr import InputXGradient, configure_interpretable_embedding_layer
from captum.attr import visualization as vis


class BERTModelWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, inputs, attention_mask):
        return self.model(inputs, attention_mask=attention_mask)[0]


def explain_text(model, text: str, y_true: int) -> None:
    tokenizer_output = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        return_attention_mask=True,
        return_tensors="pt",
    )
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer_output = tokenizer_output.to(device)
    tokens = tokenizer.convert_ids_to_tokens(tokenizer_output["input_ids"][0])

    model_copy = deepcopy(model)
    interpretable_embedding_layer = configure_interpretable_embedding_layer(
        model_copy, "distilbert.embeddings"
    )
    input_embeddings = interpretable_embedding_layer.indices_to_embeddings(
        tokenizer_output["input_ids"]
    )

    model_wrapper = BERTModelWrapper(model_copy)
    input_x_gradient = InputXGradient(model_wrapper)
    attributions = input_x_gradient.attribute(
        input_embeddings,
        target=1,
        additional_forward_args=tokenizer_output["attention_mask"],
    )

    # mean normalization
    attributions = attributions.sum(dim=-1).squeeze(0)
    attributions = attributions / torch.norm(attributions)
    attributions = list([float(attr) for attr in attributions])
    
    with torch.no_grad():
        logits = model(**tokenizer_output).logits
        y_pred_proba = softmax(logits, dim=1)[0, 1].item()
        y_pred = int(y_pred_proba >= 0.5)

    # remove [CLS] and [SEP] tokens
    attributions = attributions[1:-1]
    tokens = tokens[1:-1]
    
    vis_record = vis.VisualizationDataRecord(
        word_attributions=attributions,
        pred_prob=y_pred_proba,
        pred_class=y_pred,
        true_class=y_true,
        attr_class=1,
        attr_score=sum(attributions),
        raw_input_ids=tokens,
        convergence_score=0,
    )
    vis.visualize_text([vis_record])

# %% [markdown]
# ### Exercise 5
#
# 1. Use Captum and implemented function to explain predictions for the first 3 positive and 3 negative samples from the test set.
# 2. Comment, do you think that results make sense? Does the model focus on reasonable words, both for positive and negative sentiment?
